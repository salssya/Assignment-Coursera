# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 978us/sample - loss: 242.1464 - y1_output_loss: 115.1235 - y2_output_loss: 125.4041 - y1_output_root_mean_squared_error: 10.7694 - y2_output_root_mean_squared_error: 11.2324 - val_loss: 53.1973 - val_y1_output_loss: 14.8792 - val_y2_output_loss: 38.5176 - val_y1_output_root_mean_squared_error: 3.8544 - val_y2_output_root_mean_squared_error: 6.1920
# Epoch 2/500
# 614/614 [==============================] - 0s 156us/sample - loss: 33.8432 - y1_output_loss: 13.0537 - y2_output_loss: 21.1957 - y1_output_root_mean_squared_error: 3.6142 - y2_output_root_mean_squared_error: 4.5586 - val_loss: 55.8836 - val_y1_output_loss: 9.2333 - val_y2_output_loss: 45.9806 - val_y1_output_root_mean_squared_error: 3.0563 - val_y2_output_root_mean_squared_error: 6.8222
# Epoch 3/500
# 614/614 [==============================] - 0s 136us/sample - loss: 25.9413 - y1_output_loss: 10.2976 - y2_output_loss: 15.5993 - y1_output_root_mean_squared_error: 3.1983 - y2_output_root_mean_squared_error: 3.9639 - val_loss: 26.7013 - val_y1_output_loss: 10.0059 - val_y2_output_loss: 15.9528 - val_y1_output_root_mean_squared_error: 3.2106 - val_y2_output_root_mean_squared_error: 4.0489
# Epoch 4/500
# 614/614 [==============================] - 0s 137us/sample - loss: 28.2524 - y1_output_loss: 10.8484 - y2_output_loss: 17.7240 - y1_output_root_mean_squared_error: 3.2773 - y2_output_root_mean_squared_error: 4.1847 - val_loss: 40.5960 - val_y1_output_loss: 9.9597 - val_y2_output_loss: 29.6106 - val_y1_output_root_mean_squared_error: 3.2078 - val_y2_output_root_mean_squared_error: 5.5051
# Epoch 5/500
# 614/614 [==============================] - 0s 137us/sample - loss: 22.1927 - y1_output_loss: 9.1486 - y2_output_loss: 13.1529 - y1_output_root_mean_squared_error: 3.0191 - y2_output_root_mean_squared_error: 3.6163 - val_loss: 67.4677 - val_y1_output_loss: 15.9090 - val_y2_output_loss: 50.5064 - val_y1_output_root_mean_squared_error: 4.0211 - val_y2_output_root_mean_squared_error: 7.1623
# Epoch 6/500
# 614/614 [==============================] - 0s 144us/sample - loss: 24.9559 - y1_output_loss: 9.7334 - y2_output_loss: 15.5394 - y1_output_root_mean_squared_error: 3.0963 - y2_output_root_mean_squared_error: 3.9203 - val_loss: 36.9812 - val_y1_output_loss: 9.3897 - val_y2_output_loss: 26.5540 - val_y1_output_root_mean_squared_error: 3.1169 - val_y2_output_root_mean_squared_error: 5.2217
# Epoch 7/500
# 614/614 [==============================] - 0s 144us/sample - loss: 21.5792 - y1_output_loss: 8.7940 - y2_output_loss: 12.6524 - y1_output_root_mean_squared_error: 2.9748 - y2_output_root_mean_squared_error: 3.5679 - val_loss: 19.0539 - val_y1_output_loss: 7.7917 - val_y2_output_loss: 10.6680 - val_y1_output_root_mean_squared_error: 2.8380 - val_y2_output_root_mean_squared_error: 3.3166
# Epoch 8/500
# 614/614 [==============================] - 0s 143us/sample - loss: 25.2827 - y1_output_loss: 9.5899 - y2_output_loss: 15.8162 - y1_output_root_mean_squared_error: 3.0827 - y2_output_root_mean_squared_error: 3.9724 - val_loss: 38.5164 - val_y1_output_loss: 12.1901 - val_y2_output_loss: 25.8575 - val_y1_output_root_mean_squared_error: 3.5098 - val_y2_output_root_mean_squared_error: 5.1184
# Epoch 9/500
# 614/614 [==============================] - 0s 134us/sample - loss: 22.7892 - y1_output_loss: 8.7366 - y2_output_loss: 13.8652 - y1_output_root_mean_squared_error: 2.9688 - y2_output_root_mean_squared_error: 3.7384 - val_loss: 20.4247 - val_y1_output_loss: 7.8458 - val_y2_output_loss: 11.8832 - val_y1_output_root_mean_squared_error: 2.8524 - val_y2_output_root_mean_squared_error: 3.5055
# Epoch 10/500
# 614/614 [==============================] - 0s 135us/sample - loss: 20.7156 - y1_output_loss: 8.1306 - y2_output_loss: 12.6148 - y1_output_root_mean_squared_error: 2.8579 - y2_output_root_mean_squared_error: 3.5423 - val_loss: 29.5909 - val_y1_output_loss: 11.0525 - val_y2_output_loss: 17.7193 - val_y1_output_root_mean_squared_error: 3.3757 - val_y2_output_root_mean_squared_error: 4.2656
# Epoch 11/500
# 614/614 [==============================] - 0s 134us/sample - loss: 21.6263 - y1_output_loss: 8.1886 - y2_output_loss: 13.3810 - y1_output_root_mean_squared_error: 2.8550 - y2_output_root_mean_squared_error: 3.6709 - val_loss: 25.1684 - val_y1_output_loss: 8.7233 - val_y2_output_loss: 15.9578 - val_y1_output_root_mean_squared_error: 2.9825 - val_y2_output_root_mean_squared_error: 4.0340
# Epoch 12/500
# 614/614 [==============================] - 0s 139us/sample - loss: 19.1725 - y1_output_loss: 8.0413 - y2_output_loss: 11.2340 - y1_output_root_mean_squared_error: 2.8384 - y2_output_root_mean_squared_error: 3.3341 - val_loss: 23.9980 - val_y1_output_loss: 9.4730 - val_y2_output_loss: 13.6631 - val_y1_output_root_mean_squared_error: 3.1351 - val_y2_output_root_mean_squared_error: 3.7642
# Epoch 13/500
# 614/614 [==============================] - 0s 139us/sample - loss: 18.0775 - y1_output_loss: 7.6297 - y2_output_loss: 10.3494 - y1_output_root_mean_squared_error: 2.7710 - y2_output_root_mean_squared_error: 3.2247 - val_loss: 16.5294 - val_y1_output_loss: 6.6029 - val_y2_output_loss: 9.3792 - val_y1_output_root_mean_squared_error: 2.6150 - val_y2_output_root_mean_squared_error: 3.1130
# Epoch 14/500
# 614/614 [==============================] - 0s 143us/sample - loss: 19.2308 - y1_output_loss: 7.5488 - y2_output_loss: 11.6418 - y1_output_root_mean_squared_error: 2.7382 - y2_output_root_mean_squared_error: 3.4254 - val_loss: 24.5025 - val_y1_output_loss: 10.5349 - val_y2_output_loss: 13.1486 - val_y1_output_root_mean_squared_error: 3.3020 - val_y2_output_root_mean_squared_error: 3.6877
# Epoch 15/500
# 614/614 [==============================] - 0s 145us/sample - loss: 21.6713 - y1_output_loss: 7.8780 - y2_output_loss: 13.6845 - y1_output_root_mean_squared_error: 2.8036 - y2_output_root_mean_squared_error: 3.7163 - val_loss: 21.9242 - val_y1_output_loss: 7.9887 - val_y2_output_loss: 13.4673 - val_y1_output_root_mean_squared_error: 2.8559 - val_y2_output_root_mean_squared_error: 3.7106
# Epoch 16/500
# 614/614 [==============================] - 0s 139us/sample - loss: 29.1725 - y1_output_loss: 9.4782 - y2_output_loss: 19.9384 - y1_output_root_mean_squared_error: 3.0711 - y2_output_root_mean_squared_error: 4.4430 - val_loss: 83.8954 - val_y1_output_loss: 19.7663 - val_y2_output_loss: 61.7515 - val_y1_output_root_mean_squared_error: 4.5239 - val_y2_output_root_mean_squared_error: 7.9643
# Epoch 17/500
# 614/614 [==============================] - 0s 139us/sample - loss: 22.6199 - y1_output_loss: 8.1051 - y2_output_loss: 14.4242 - y1_output_root_mean_squared_error: 2.8572 - y2_output_root_mean_squared_error: 3.8021 - val_loss: 17.3855 - val_y1_output_loss: 6.0765 - val_y2_output_loss: 10.7689 - val_y1_output_root_mean_squared_error: 2.5062 - val_y2_output_root_mean_squared_error: 3.3323
# Epoch 18/500
# 614/614 [==============================] - 0s 150us/sample - loss: 16.8915 - y1_output_loss: 6.3133 - y2_output_loss: 10.6496 - y1_output_root_mean_squared_error: 2.4985 - y2_output_root_mean_squared_error: 3.2633 - val_loss: 17.5680 - val_y1_output_loss: 7.1454 - val_y2_output_loss: 9.8340 - val_y1_output_root_mean_squared_error: 2.7210 - val_y2_output_root_mean_squared_error: 3.1881
# Epoch 19/500
# 614/614 [==============================] - 0s 143us/sample - loss: 19.8081 - y1_output_loss: 7.1701 - y2_output_loss: 12.5056 - y1_output_root_mean_squared_error: 2.6869 - y2_output_root_mean_squared_error: 3.5480 - val_loss: 29.3397 - val_y1_output_loss: 9.8518 - val_y2_output_loss: 18.4997 - val_y1_output_root_mean_squared_error: 3.1963 - val_y2_output_root_mean_squared_error: 4.3730
# Epoch 20/500
# 614/614 [==============================] - 0s 133us/sample - loss: 15.8401 - y1_output_loss: 6.2934 - y2_output_loss: 9.6936 - y1_output_root_mean_squared_error: 2.4996 - y2_output_root_mean_squared_error: 3.0971 - val_loss: 15.7801 - val_y1_output_loss: 5.9258 - val_y2_output_loss: 9.3044 - val_y1_output_root_mean_squared_error: 2.4788 - val_y2_output_root_mean_squared_error: 3.1041
# Epoch 21/500
# 614/614 [==============================] - 0s 136us/sample - loss: 14.5989 - y1_output_loss: 5.9217 - y2_output_loss: 8.9612 - y1_output_root_mean_squared_error: 2.4232 - y2_output_root_mean_squared_error: 2.9541 - val_loss: 21.9139 - val_y1_output_loss: 6.8414 - val_y2_output_loss: 14.3122 - val_y1_output_root_mean_squared_error: 2.6648 - val_y2_output_root_mean_squared_error: 3.8488
# Epoch 22/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.2610 - y1_output_loss: 5.9419 - y2_output_loss: 9.2152 - y1_output_root_mean_squared_error: 2.4440 - y2_output_root_mean_squared_error: 3.0476 - val_loss: 20.8845 - val_y1_output_loss: 7.2167 - val_y2_output_loss: 13.4716 - val_y1_output_root_mean_squared_error: 2.6933 - val_y2_output_root_mean_squared_error: 3.6919
# Epoch 23/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.7266 - y1_output_loss: 5.1099 - y2_output_loss: 7.5478 - y1_output_root_mean_squared_error: 2.2645 - y2_output_root_mean_squared_error: 2.7566 - val_loss: 14.1896 - val_y1_output_loss: 5.5164 - val_y2_output_loss: 8.1462 - val_y1_output_root_mean_squared_error: 2.3933 - val_y2_output_root_mean_squared_error: 2.9089
# Epoch 24/500
# 614/614 [==============================] - 0s 136us/sample - loss: 14.2932 - y1_output_loss: 5.3830 - y2_output_loss: 8.7930 - y1_output_root_mean_squared_error: 2.3311 - y2_output_root_mean_squared_error: 2.9764 - val_loss: 15.5955 - val_y1_output_loss: 6.5134 - val_y2_output_loss: 8.5088 - val_y1_output_root_mean_squared_error: 2.5999 - val_y2_output_root_mean_squared_error: 2.9725
# Epoch 25/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.4081 - y1_output_loss: 5.4717 - y2_output_loss: 8.8323 - y1_output_root_mean_squared_error: 2.3434 - y2_output_root_mean_squared_error: 2.9861 - val_loss: 14.7035 - val_y1_output_loss: 5.9339 - val_y2_output_loss: 8.2331 - val_y1_output_root_mean_squared_error: 2.4827 - val_y2_output_root_mean_squared_error: 2.9223
# Epoch 26/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.7868 - y1_output_loss: 5.4425 - y2_output_loss: 9.3143 - y1_output_root_mean_squared_error: 2.3389 - y2_output_root_mean_squared_error: 3.0522 - val_loss: 14.8657 - val_y1_output_loss: 6.6716 - val_y2_output_loss: 7.6563 - val_y1_output_root_mean_squared_error: 2.6308 - val_y2_output_root_mean_squared_error: 2.8187
# Epoch 27/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.3552 - y1_output_loss: 5.1749 - y2_output_loss: 8.0599 - y1_output_root_mean_squared_error: 2.2859 - y2_output_root_mean_squared_error: 2.8513 - val_loss: 14.2803 - val_y1_output_loss: 5.9273 - val_y2_output_loss: 7.8420 - val_y1_output_root_mean_squared_error: 2.4785 - val_y2_output_root_mean_squared_error: 2.8526
# Epoch 28/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.4760 - y1_output_loss: 5.0263 - y2_output_loss: 8.4248 - y1_output_root_mean_squared_error: 2.2439 - y2_output_root_mean_squared_error: 2.9053 - val_loss: 12.6442 - val_y1_output_loss: 4.9961 - val_y2_output_loss: 7.2228 - val_y1_output_root_mean_squared_error: 2.2748 - val_y2_output_root_mean_squared_error: 2.7331
# Epoch 29/500
# 614/614 [==============================] - 0s 142us/sample - loss: 13.1340 - y1_output_loss: 4.8311 - y2_output_loss: 8.2174 - y1_output_root_mean_squared_error: 2.2019 - y2_output_root_mean_squared_error: 2.8785 - val_loss: 14.3708 - val_y1_output_loss: 5.0459 - val_y2_output_loss: 8.8852 - val_y1_output_root_mean_squared_error: 2.2818 - val_y2_output_root_mean_squared_error: 3.0272
# Epoch 30/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.4843 - y1_output_loss: 4.4511 - y2_output_loss: 7.2584 - y1_output_root_mean_squared_error: 2.1070 - y2_output_root_mean_squared_error: 2.6542 - val_loss: 68.7740 - val_y1_output_loss: 14.5692 - val_y2_output_loss: 52.8585 - val_y1_output_root_mean_squared_error: 3.8663 - val_y2_output_root_mean_squared_error: 7.3366
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 14.7318 - y1_output_loss: 4.8120 - y2_output_loss: 9.9076 - y1_output_root_mean_squared_error: 2.1989 - y2_output_root_mean_squared_error: 3.1459 - val_loss: 18.9406 - val_y1_output_loss: 5.7975 - val_y2_output_loss: 12.7808 - val_y1_output_root_mean_squared_error: 2.4303 - val_y2_output_root_mean_squared_error: 3.6103
# Epoch 32/500
# 614/614 [==============================] - 0s 138us/sample - loss: 11.5809 - y1_output_loss: 4.1545 - y2_output_loss: 7.3325 - y1_output_root_mean_squared_error: 2.0475 - y2_output_root_mean_squared_error: 2.7182 - val_loss: 10.8834 - val_y1_output_loss: 3.8487 - val_y2_output_loss: 6.6683 - val_y1_output_root_mean_squared_error: 1.9957 - val_y2_output_root_mean_squared_error: 2.6269
# Epoch 33/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.9943 - y1_output_loss: 4.1637 - y2_output_loss: 7.1542 - y1_output_root_mean_squared_error: 2.0130 - y2_output_root_mean_squared_error: 2.6348 - val_loss: 46.1477 - val_y1_output_loss: 13.9761 - val_y2_output_loss: 31.7986 - val_y1_output_root_mean_squared_error: 3.7420 - val_y2_output_root_mean_squared_error: 5.6697
# Epoch 34/500
# 614/614 [==============================] - 0s 134us/sample - loss: 11.8850 - y1_output_loss: 4.2851 - y2_output_loss: 7.5542 - y1_output_root_mean_squared_error: 2.0743 - y2_output_root_mean_squared_error: 2.7536 - val_loss: 15.8167 - val_y1_output_loss: 5.0908 - val_y2_output_loss: 10.2434 - val_y1_output_root_mean_squared_error: 2.2958 - val_y2_output_root_mean_squared_error: 3.2475
# Epoch 35/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.5186 - y1_output_loss: 4.0513 - y2_output_loss: 6.5048 - y1_output_root_mean_squared_error: 2.0034 - y2_output_root_mean_squared_error: 2.5505 - val_loss: 18.7520 - val_y1_output_loss: 4.8613 - val_y2_output_loss: 13.4145 - val_y1_output_root_mean_squared_error: 2.2364 - val_y2_output_root_mean_squared_error: 3.7082
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.4720 - y1_output_loss: 3.7160 - y2_output_loss: 6.7961 - y1_output_root_mean_squared_error: 1.9346 - y2_output_root_mean_squared_error: 2.5941 - val_loss: 14.0244 - val_y1_output_loss: 5.4313 - val_y2_output_loss: 8.1591 - val_y1_output_root_mean_squared_error: 2.3684 - val_y2_output_root_mean_squared_error: 2.9009
# Epoch 37/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.3928 - y1_output_loss: 3.5142 - y2_output_loss: 6.7905 - y1_output_root_mean_squared_error: 1.8826 - y2_output_root_mean_squared_error: 2.6170 - val_loss: 9.5730 - val_y1_output_loss: 3.7526 - val_y2_output_loss: 5.4770 - val_y1_output_root_mean_squared_error: 1.9727 - val_y2_output_root_mean_squared_error: 2.3836
# Epoch 38/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.6586 - y1_output_loss: 3.1402 - y2_output_loss: 5.5115 - y1_output_root_mean_squared_error: 1.7795 - y2_output_root_mean_squared_error: 2.3435 - val_loss: 30.4095 - val_y1_output_loss: 7.2522 - val_y2_output_loss: 22.4216 - val_y1_output_root_mean_squared_error: 2.7354 - val_y2_output_root_mean_squared_error: 4.7882
# Epoch 39/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.2171 - y1_output_loss: 3.4063 - y2_output_loss: 5.7669 - y1_output_root_mean_squared_error: 1.8458 - y2_output_root_mean_squared_error: 2.4104 - val_loss: 9.6615 - val_y1_output_loss: 3.2181 - val_y2_output_loss: 6.1438 - val_y1_output_root_mean_squared_error: 1.8211 - val_y2_output_root_mean_squared_error: 2.5190
# Epoch 40/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.3578 - y1_output_loss: 3.5136 - y2_output_loss: 7.3393 - y1_output_root_mean_squared_error: 1.8303 - y2_output_root_mean_squared_error: 2.6472 - val_loss: 70.3212 - val_y1_output_loss: 16.8633 - val_y2_output_loss: 51.3285 - val_y1_output_root_mean_squared_error: 4.1767 - val_y2_output_root_mean_squared_error: 7.2716
# Epoch 41/500
# 614/614 [==============================] - 0s 136us/sample - loss: 17.6673 - y1_output_loss: 5.2082 - y2_output_loss: 12.3244 - y1_output_root_mean_squared_error: 2.2922 - y2_output_root_mean_squared_error: 3.5232 - val_loss: 11.6053 - val_y1_output_loss: 4.1512 - val_y2_output_loss: 7.0661 - val_y1_output_root_mean_squared_error: 2.0737 - val_y2_output_root_mean_squared_error: 2.7028
# Epoch 42/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.3446 - y1_output_loss: 3.2335 - y2_output_loss: 6.0696 - y1_output_root_mean_squared_error: 1.7941 - y2_output_root_mean_squared_error: 2.4750 - val_loss: 10.0647 - val_y1_output_loss: 3.6717 - val_y2_output_loss: 6.0949 - val_y1_output_root_mean_squared_error: 1.9401 - val_y2_output_root_mean_squared_error: 2.5101
# Epoch 43/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.2325 - y1_output_loss: 2.7956 - y2_output_loss: 5.4552 - y1_output_root_mean_squared_error: 1.6782 - y2_output_root_mean_squared_error: 2.3272 - val_loss: 19.7222 - val_y1_output_loss: 5.6773 - val_y2_output_loss: 13.5717 - val_y1_output_root_mean_squared_error: 2.4168 - val_y2_output_root_mean_squared_error: 3.7258
# Epoch 44/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.1606 - y1_output_loss: 3.3526 - y2_output_loss: 8.1586 - y1_output_root_mean_squared_error: 1.8267 - y2_output_root_mean_squared_error: 2.7971 - val_loss: 17.5107 - val_y1_output_loss: 5.0010 - val_y2_output_loss: 11.9072 - val_y1_output_root_mean_squared_error: 2.2772 - val_y2_output_root_mean_squared_error: 3.5107
# Epoch 45/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.4367 - y1_output_loss: 3.6147 - y2_output_loss: 6.7579 - y1_output_root_mean_squared_error: 1.9084 - y2_output_root_mean_squared_error: 2.6066 - val_loss: 12.4330 - val_y1_output_loss: 4.1513 - val_y2_output_loss: 7.9342 - val_y1_output_root_mean_squared_error: 2.0700 - val_y2_output_root_mean_squared_error: 2.8545
# Epoch 46/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.4384 - y1_output_loss: 2.5045 - y2_output_loss: 4.9428 - y1_output_root_mean_squared_error: 1.5791 - y2_output_root_mean_squared_error: 2.2237 - val_loss: 15.4900 - val_y1_output_loss: 4.3260 - val_y2_output_loss: 10.9299 - val_y1_output_root_mean_squared_error: 2.0878 - val_y2_output_root_mean_squared_error: 3.3363
# Epoch 47/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.8734 - y1_output_loss: 2.3774 - y2_output_loss: 5.8674 - y1_output_root_mean_squared_error: 1.5333 - y2_output_root_mean_squared_error: 2.3500 - val_loss: 97.3052 - val_y1_output_loss: 19.3152 - val_y2_output_loss: 76.8471 - val_y1_output_root_mean_squared_error: 4.4257 - val_y2_output_root_mean_squared_error: 8.8158
# Epoch 48/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.7259 - y1_output_loss: 2.8217 - y2_output_loss: 5.9090 - y1_output_root_mean_squared_error: 1.6702 - y2_output_root_mean_squared_error: 2.4364 - val_loss: 9.0890 - val_y1_output_loss: 4.0694 - val_y2_output_loss: 4.7847 - val_y1_output_root_mean_squared_error: 2.0402 - val_y2_output_root_mean_squared_error: 2.2196
# Epoch 49/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.3593 - y1_output_loss: 2.3437 - y2_output_loss: 5.0566 - y1_output_root_mean_squared_error: 1.5232 - y2_output_root_mean_squared_error: 2.2448 - val_loss: 13.0916 - val_y1_output_loss: 4.6779 - val_y2_output_loss: 8.0726 - val_y1_output_root_mean_squared_error: 2.1937 - val_y2_output_root_mean_squared_error: 2.8773
# Epoch 50/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.5095 - y1_output_loss: 2.8216 - y2_output_loss: 4.8446 - y1_output_root_mean_squared_error: 1.6443 - y2_output_root_mean_squared_error: 2.1922 - val_loss: 15.2003 - val_y1_output_loss: 5.0039 - val_y2_output_loss: 9.6682 - val_y1_output_root_mean_squared_error: 2.2779 - val_y2_output_root_mean_squared_error: 3.1641
# Epoch 51/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.1301 - y1_output_loss: 2.6136 - y2_output_loss: 5.5928 - y1_output_root_mean_squared_error: 1.6154 - y2_output_root_mean_squared_error: 2.3496 - val_loss: 8.8509 - val_y1_output_loss: 2.5577 - val_y2_output_loss: 6.0821 - val_y1_output_root_mean_squared_error: 1.6145 - val_y2_output_root_mean_squared_error: 2.4989
# Epoch 52/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.7113 - y1_output_loss: 2.4490 - y2_output_loss: 5.2318 - y1_output_root_mean_squared_error: 1.5678 - y2_output_root_mean_squared_error: 2.2920 - val_loss: 7.5659 - val_y1_output_loss: 2.6383 - val_y2_output_loss: 4.7058 - val_y1_output_root_mean_squared_error: 1.6466 - val_y2_output_root_mean_squared_error: 2.2033
# Epoch 53/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.3126 - y1_output_loss: 2.0093 - y2_output_loss: 4.2820 - y1_output_root_mean_squared_error: 1.4231 - y2_output_root_mean_squared_error: 2.0706 - val_loss: 12.6613 - val_y1_output_loss: 3.9365 - val_y2_output_loss: 8.5102 - val_y1_output_root_mean_squared_error: 2.0042 - val_y2_output_root_mean_squared_error: 2.9401
# Epoch 54/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.3409 - y1_output_loss: 2.0957 - y2_output_loss: 5.2904 - y1_output_root_mean_squared_error: 1.4532 - y2_output_root_mean_squared_error: 2.2867 - val_loss: 7.4636 - val_y1_output_loss: 2.7168 - val_y2_output_loss: 4.5316 - val_y1_output_root_mean_squared_error: 1.6732 - val_y2_output_root_mean_squared_error: 2.1596
# Epoch 55/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.5398 - y1_output_loss: 2.0499 - y2_output_loss: 4.4619 - y1_output_root_mean_squared_error: 1.4336 - y2_output_root_mean_squared_error: 2.1177 - val_loss: 8.9468 - val_y1_output_loss: 2.8116 - val_y2_output_loss: 5.9223 - val_y1_output_root_mean_squared_error: 1.6991 - val_y2_output_root_mean_squared_error: 2.4617
# Epoch 56/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.9184 - y1_output_loss: 2.1390 - y2_output_loss: 4.7404 - y1_output_root_mean_squared_error: 1.4687 - y2_output_root_mean_squared_error: 2.1820 - val_loss: 8.0019 - val_y1_output_loss: 2.5261 - val_y2_output_loss: 5.2567 - val_y1_output_root_mean_squared_error: 1.6060 - val_y2_output_root_mean_squared_error: 2.3287
# Epoch 57/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.3315 - y1_output_loss: 2.6547 - y2_output_loss: 5.6125 - y1_output_root_mean_squared_error: 1.6336 - y2_output_root_mean_squared_error: 2.3796 - val_loss: 6.7639 - val_y1_output_loss: 2.3805 - val_y2_output_loss: 4.1730 - val_y1_output_root_mean_squared_error: 1.5654 - val_y2_output_root_mean_squared_error: 2.0769
# Epoch 58/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.7080 - y1_output_loss: 2.2449 - y2_output_loss: 4.5121 - y1_output_root_mean_squared_error: 1.4889 - y2_output_root_mean_squared_error: 2.1193 - val_loss: 13.9542 - val_y1_output_loss: 5.7407 - val_y2_output_loss: 7.8855 - val_y1_output_root_mean_squared_error: 2.4244 - val_y2_output_root_mean_squared_error: 2.8419
# Epoch 59/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.5823 - y1_output_loss: 1.9419 - y2_output_loss: 4.6597 - y1_output_root_mean_squared_error: 1.3903 - y2_output_root_mean_squared_error: 2.1562 - val_loss: 7.8059 - val_y1_output_loss: 2.4917 - val_y2_output_loss: 5.1619 - val_y1_output_root_mean_squared_error: 1.5856 - val_y2_output_root_mean_squared_error: 2.3004
# Epoch 60/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.5695 - y1_output_loss: 1.9961 - y2_output_loss: 4.5522 - y1_output_root_mean_squared_error: 1.4163 - y2_output_root_mean_squared_error: 2.1363 - val_loss: 11.0076 - val_y1_output_loss: 2.9317 - val_y2_output_loss: 7.8223 - val_y1_output_root_mean_squared_error: 1.7278 - val_y2_output_root_mean_squared_error: 2.8324
# Epoch 61/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.2298 - y1_output_loss: 1.8830 - y2_output_loss: 4.3241 - y1_output_root_mean_squared_error: 1.3737 - y2_output_root_mean_squared_error: 2.0839 - val_loss: 7.4712 - val_y1_output_loss: 2.9488 - val_y2_output_loss: 4.3304 - val_y1_output_root_mean_squared_error: 1.7368 - val_y2_output_root_mean_squared_error: 2.1106
# Epoch 62/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.3694 - y1_output_loss: 2.1604 - y2_output_loss: 5.1752 - y1_output_root_mean_squared_error: 1.4716 - y2_output_root_mean_squared_error: 2.2812 - val_loss: 8.4688 - val_y1_output_loss: 2.7447 - val_y2_output_loss: 5.4982 - val_y1_output_root_mean_squared_error: 1.6817 - val_y2_output_root_mean_squared_error: 2.3750
# Epoch 63/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.6861 - y1_output_loss: 1.7332 - y2_output_loss: 3.9078 - y1_output_root_mean_squared_error: 1.3220 - y2_output_root_mean_squared_error: 1.9846 - val_loss: 8.3830 - val_y1_output_loss: 2.2047 - val_y2_output_loss: 5.9032 - val_y1_output_root_mean_squared_error: 1.5087 - val_y2_output_root_mean_squared_error: 2.4712
# Epoch 64/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.1595 - y1_output_loss: 1.9453 - y2_output_loss: 4.2330 - y1_output_root_mean_squared_error: 1.3893 - y2_output_root_mean_squared_error: 2.0566 - val_loss: 6.1356 - val_y1_output_loss: 2.1510 - val_y2_output_loss: 3.8285 - val_y1_output_root_mean_squared_error: 1.4815 - val_y2_output_root_mean_squared_error: 1.9851
# Epoch 65/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1868 - y1_output_loss: 1.7887 - y2_output_loss: 4.3596 - y1_output_root_mean_squared_error: 1.3430 - y2_output_root_mean_squared_error: 2.0936 - val_loss: 5.9498 - val_y1_output_loss: 1.9041 - val_y2_output_loss: 3.8995 - val_y1_output_root_mean_squared_error: 1.3988 - val_y2_output_root_mean_squared_error: 1.9983
# Epoch 66/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.7572 - y1_output_loss: 1.9137 - y2_output_loss: 4.8175 - y1_output_root_mean_squared_error: 1.3759 - y2_output_root_mean_squared_error: 2.2055 - val_loss: 5.5206 - val_y1_output_loss: 2.1073 - val_y2_output_loss: 3.3104 - val_y1_output_root_mean_squared_error: 1.4605 - val_y2_output_root_mean_squared_error: 1.8405
# Epoch 67/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.1265 - y1_output_loss: 2.7919 - y2_output_loss: 6.2573 - y1_output_root_mean_squared_error: 1.6788 - y2_output_root_mean_squared_error: 2.5116 - val_loss: 9.4504 - val_y1_output_loss: 3.6980 - val_y2_output_loss: 5.6580 - val_y1_output_root_mean_squared_error: 1.9317 - val_y2_output_root_mean_squared_error: 2.3914
# Epoch 68/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.7947 - y1_output_loss: 2.1990 - y2_output_loss: 5.7205 - y1_output_root_mean_squared_error: 1.4869 - y2_output_root_mean_squared_error: 2.3630 - val_loss: 34.0677 - val_y1_output_loss: 5.4387 - val_y2_output_loss: 27.6689 - val_y1_output_root_mean_squared_error: 2.3742 - val_y2_output_root_mean_squared_error: 5.3321
# Epoch 69/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.3433 - y1_output_loss: 1.5615 - y2_output_loss: 3.8369 - y1_output_root_mean_squared_error: 1.2518 - y2_output_root_mean_squared_error: 1.9432 - val_loss: 16.1244 - val_y1_output_loss: 2.6450 - val_y2_output_loss: 13.1520 - val_y1_output_root_mean_squared_error: 1.6520 - val_y2_output_root_mean_squared_error: 3.6600
# Epoch 70/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.7023 - y1_output_loss: 1.9227 - y2_output_loss: 4.7497 - y1_output_root_mean_squared_error: 1.3825 - y2_output_root_mean_squared_error: 2.1888 - val_loss: 7.5911 - val_y1_output_loss: 1.8210 - val_y2_output_loss: 5.5168 - val_y1_output_root_mean_squared_error: 1.3738 - val_y2_output_root_mean_squared_error: 2.3883
# Epoch 71/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.1981 - y1_output_loss: 1.5645 - y2_output_loss: 3.6684 - y1_output_root_mean_squared_error: 1.2526 - y2_output_root_mean_squared_error: 1.9051 - val_loss: 20.3787 - val_y1_output_loss: 4.5916 - val_y2_output_loss: 15.5522 - val_y1_output_root_mean_squared_error: 2.1583 - val_y2_output_root_mean_squared_error: 3.9649
# Epoch 72/500
# 614/614 [==============================] - 0s 137us/sample - loss: 13.0416 - y1_output_loss: 3.8147 - y2_output_loss: 9.1147 - y1_output_root_mean_squared_error: 1.9618 - y2_output_root_mean_squared_error: 3.0320 - val_loss: 6.6860 - val_y1_output_loss: 2.2722 - val_y2_output_loss: 4.2656 - val_y1_output_root_mean_squared_error: 1.5182 - val_y2_output_root_mean_squared_error: 2.0931
# Epoch 73/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.7925 - y1_output_loss: 1.7126 - y2_output_loss: 4.1633 - y1_output_root_mean_squared_error: 1.2913 - y2_output_root_mean_squared_error: 2.0310 - val_loss: 5.1307 - val_y1_output_loss: 1.3441 - val_y2_output_loss: 3.6415 - val_y1_output_root_mean_squared_error: 1.1799 - val_y2_output_root_mean_squared_error: 1.9335
# Epoch 74/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.2593 - y1_output_loss: 1.4479 - y2_output_loss: 3.7636 - y1_output_root_mean_squared_error: 1.2087 - y2_output_root_mean_squared_error: 1.9489 - val_loss: 4.4261 - val_y1_output_loss: 1.2537 - val_y2_output_loss: 3.0291 - val_y1_output_root_mean_squared_error: 1.1371 - val_y2_output_root_mean_squared_error: 1.7700
# Epoch 75/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.8473 - y1_output_loss: 1.4114 - y2_output_loss: 3.5509 - y1_output_root_mean_squared_error: 1.1780 - y2_output_root_mean_squared_error: 1.8600 - val_loss: 20.0509 - val_y1_output_loss: 4.1226 - val_y2_output_loss: 15.4918 - val_y1_output_root_mean_squared_error: 2.0604 - val_y2_output_root_mean_squared_error: 3.9756
# Epoch 76/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.5896 - y1_output_loss: 1.8716 - y2_output_loss: 4.6572 - y1_output_root_mean_squared_error: 1.3743 - y2_output_root_mean_squared_error: 2.1682 - val_loss: 4.9487 - val_y1_output_loss: 1.6371 - val_y2_output_loss: 3.1428 - val_y1_output_root_mean_squared_error: 1.2998 - val_y2_output_root_mean_squared_error: 1.8053
# Epoch 77/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.4369 - y1_output_loss: 1.2977 - y2_output_loss: 3.1765 - y1_output_root_mean_squared_error: 1.1370 - y2_output_root_mean_squared_error: 1.7732 - val_loss: 10.0983 - val_y1_output_loss: 2.4038 - val_y2_output_loss: 7.3776 - val_y1_output_root_mean_squared_error: 1.5768 - val_y2_output_root_mean_squared_error: 2.7590
# Epoch 78/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.9456 - y1_output_loss: 1.3290 - y2_output_loss: 3.5883 - y1_output_root_mean_squared_error: 1.1517 - y2_output_root_mean_squared_error: 1.9024 - val_loss: 3.6783 - val_y1_output_loss: 1.0741 - val_y2_output_loss: 2.4817 - val_y1_output_root_mean_squared_error: 1.0513 - val_y2_output_root_mean_squared_error: 1.6041
# Epoch 79/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.5281 - y1_output_loss: 2.1446 - y2_output_loss: 5.3760 - y1_output_root_mean_squared_error: 1.4649 - y2_output_root_mean_squared_error: 2.3200 - val_loss: 5.3688 - val_y1_output_loss: 1.0136 - val_y2_output_loss: 4.2153 - val_y1_output_root_mean_squared_error: 1.0210 - val_y2_output_root_mean_squared_error: 2.0800
# Epoch 80/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.8383 - y1_output_loss: 1.2350 - y2_output_loss: 3.6239 - y1_output_root_mean_squared_error: 1.1006 - y2_output_root_mean_squared_error: 1.9044 - val_loss: 3.7234 - val_y1_output_loss: 1.3286 - val_y2_output_loss: 2.2750 - val_y1_output_root_mean_squared_error: 1.1686 - val_y2_output_root_mean_squared_error: 1.5355
# Epoch 81/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4042 - y1_output_loss: 0.9818 - y2_output_loss: 2.4333 - y1_output_root_mean_squared_error: 0.9869 - y2_output_root_mean_squared_error: 1.5589 - val_loss: 6.0366 - val_y1_output_loss: 0.9863 - val_y2_output_loss: 4.8564 - val_y1_output_root_mean_squared_error: 1.0108 - val_y2_output_root_mean_squared_error: 2.2394
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.4752 - y1_output_loss: 1.2438 - y2_output_loss: 3.2405 - y1_output_root_mean_squared_error: 1.1197 - y2_output_root_mean_squared_error: 1.7948 - val_loss: 7.4044 - val_y1_output_loss: 1.0283 - val_y2_output_loss: 6.1886 - val_y1_output_root_mean_squared_error: 1.0270 - val_y2_output_root_mean_squared_error: 2.5199
# Epoch 83/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.8320 - y1_output_loss: 1.2604 - y2_output_loss: 3.6456 - y1_output_root_mean_squared_error: 1.1150 - y2_output_root_mean_squared_error: 1.8944 - val_loss: 20.1101 - val_y1_output_loss: 5.5045 - val_y2_output_loss: 14.0265 - val_y1_output_root_mean_squared_error: 2.3810 - val_y2_output_root_mean_squared_error: 3.8001
# Epoch 84/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.2587 - y1_output_loss: 2.5988 - y2_output_loss: 5.6173 - y1_output_root_mean_squared_error: 1.6137 - y2_output_root_mean_squared_error: 2.3780 - val_loss: 3.8319 - val_y1_output_loss: 1.1272 - val_y2_output_loss: 2.5762 - val_y1_output_root_mean_squared_error: 1.0783 - val_y2_output_root_mean_squared_error: 1.6338
# Epoch 85/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.8905 - y1_output_loss: 1.2742 - y2_output_loss: 3.6156 - y1_output_root_mean_squared_error: 1.1232 - y2_output_root_mean_squared_error: 1.9050 - val_loss: 7.9987 - val_y1_output_loss: 1.8138 - val_y2_output_loss: 5.9518 - val_y1_output_root_mean_squared_error: 1.3639 - val_y2_output_root_mean_squared_error: 2.4776
# Epoch 86/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.8844 - y1_output_loss: 1.2066 - y2_output_loss: 3.6500 - y1_output_root_mean_squared_error: 1.1020 - y2_output_root_mean_squared_error: 1.9157 - val_loss: 3.7850 - val_y1_output_loss: 1.1058 - val_y2_output_loss: 2.6098 - val_y1_output_root_mean_squared_error: 1.0664 - val_y2_output_root_mean_squared_error: 1.6272
# Epoch 87/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.6280 - y1_output_loss: 1.2145 - y2_output_loss: 3.4044 - y1_output_root_mean_squared_error: 1.1010 - y2_output_root_mean_squared_error: 1.8482 - val_loss: 4.1394 - val_y1_output_loss: 1.1953 - val_y2_output_loss: 2.8747 - val_y1_output_root_mean_squared_error: 1.0940 - val_y2_output_root_mean_squared_error: 1.7154
# Epoch 88/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4992 - y1_output_loss: 1.2236 - y2_output_loss: 3.3060 - y1_output_root_mean_squared_error: 1.0928 - y2_output_root_mean_squared_error: 1.8180 - val_loss: 13.2082 - val_y1_output_loss: 3.5603 - val_y2_output_loss: 9.4059 - val_y1_output_root_mean_squared_error: 1.8952 - val_y2_output_root_mean_squared_error: 3.1010
# Epoch 89/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.2899 - y1_output_loss: 1.2141 - y2_output_loss: 3.1342 - y1_output_root_mean_squared_error: 1.1013 - y2_output_root_mean_squared_error: 1.7541 - val_loss: 8.6380 - val_y1_output_loss: 1.4824 - val_y2_output_loss: 7.0274 - val_y1_output_root_mean_squared_error: 1.2357 - val_y2_output_root_mean_squared_error: 2.6667
# Epoch 90/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.0763 - y1_output_loss: 1.0905 - y2_output_loss: 2.9554 - y1_output_root_mean_squared_error: 1.0491 - y2_output_root_mean_squared_error: 1.7250 - val_loss: 4.2481 - val_y1_output_loss: 1.4835 - val_y2_output_loss: 2.6713 - val_y1_output_root_mean_squared_error: 1.2279 - val_y2_output_root_mean_squared_error: 1.6554
# Epoch 91/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.8310 - y1_output_loss: 1.0243 - y2_output_loss: 2.8335 - y1_output_root_mean_squared_error: 1.0138 - y2_output_root_mean_squared_error: 1.6743 - val_loss: 2.5033 - val_y1_output_loss: 0.6835 - val_y2_output_loss: 1.7750 - val_y1_output_root_mean_squared_error: 0.8371 - val_y2_output_root_mean_squared_error: 1.3426
# Epoch 92/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.5186 - y1_output_loss: 1.2995 - y2_output_loss: 3.2385 - y1_output_root_mean_squared_error: 1.1417 - y2_output_root_mean_squared_error: 1.7931 - val_loss: 10.7695 - val_y1_output_loss: 2.0903 - val_y2_output_loss: 8.5145 - val_y1_output_root_mean_squared_error: 1.4641 - val_y2_output_root_mean_squared_error: 2.9370
# Epoch 93/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.2909 - y1_output_loss: 2.2423 - y2_output_loss: 5.8882 - y1_output_root_mean_squared_error: 1.4295 - y2_output_root_mean_squared_error: 2.2907 - val_loss: 163.5438 - val_y1_output_loss: 69.8431 - val_y2_output_loss: 88.4460 - val_y1_output_root_mean_squared_error: 8.4987 - val_y2_output_root_mean_squared_error: 9.5559
# Epoch 94/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.0446 - y1_output_loss: 2.9134 - y2_output_loss: 5.1986 - y1_output_root_mean_squared_error: 1.7031 - y2_output_root_mean_squared_error: 2.2681 - val_loss: 28.1946 - val_y1_output_loss: 8.4595 - val_y2_output_loss: 18.9434 - val_y1_output_root_mean_squared_error: 2.9496 - val_y2_output_root_mean_squared_error: 4.4153
# Epoch 95/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.9204 - y1_output_loss: 2.4890 - y2_output_loss: 5.3589 - y1_output_root_mean_squared_error: 1.5851 - y2_output_root_mean_squared_error: 2.3255 - val_loss: 2.9440 - val_y1_output_loss: 0.7949 - val_y2_output_loss: 2.0575 - val_y1_output_root_mean_squared_error: 0.9022 - val_y2_output_root_mean_squared_error: 1.4595
# Epoch 96/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.5044 - y1_output_loss: 0.8031 - y2_output_loss: 2.6707 - y1_output_root_mean_squared_error: 0.8999 - y2_output_root_mean_squared_error: 1.6415 - val_loss: 2.6304 - val_y1_output_loss: 0.8281 - val_y2_output_loss: 1.7090 - val_y1_output_root_mean_squared_error: 0.9260 - val_y2_output_root_mean_squared_error: 1.3315
# Epoch 97/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.2879 - y1_output_loss: 1.0551 - y2_output_loss: 4.2374 - y1_output_root_mean_squared_error: 1.0208 - y2_output_root_mean_squared_error: 2.0606 - val_loss: 8.1157 - val_y1_output_loss: 2.7845 - val_y2_output_loss: 5.0622 - val_y1_output_root_mean_squared_error: 1.6969 - val_y2_output_root_mean_squared_error: 2.2883
# Epoch 98/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.7322 - y1_output_loss: 1.3097 - y2_output_loss: 3.3970 - y1_output_root_mean_squared_error: 1.1462 - y2_output_root_mean_squared_error: 1.8489 - val_loss: 8.6397 - val_y1_output_loss: 2.3132 - val_y2_output_loss: 6.1045 - val_y1_output_root_mean_squared_error: 1.5358 - val_y2_output_root_mean_squared_error: 2.5062
# Epoch 99/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.4156 - y1_output_loss: 1.1316 - y2_output_loss: 3.3096 - y1_output_root_mean_squared_error: 1.0678 - y2_output_root_mean_squared_error: 1.8098 - val_loss: 3.2665 - val_y1_output_loss: 0.6025 - val_y2_output_loss: 2.5721 - val_y1_output_root_mean_squared_error: 0.7840 - val_y2_output_root_mean_squared_error: 1.6284
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.2842 - y1_output_loss: 1.0378 - y2_output_loss: 3.2446 - y1_output_root_mean_squared_error: 1.0116 - y2_output_root_mean_squared_error: 1.8058 - val_loss: 4.3842 - val_y1_output_loss: 1.2756 - val_y2_output_loss: 2.9739 - val_y1_output_root_mean_squared_error: 1.1447 - val_y2_output_root_mean_squared_error: 1.7533
# Epoch 101/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.2261 - y1_output_loss: 0.8135 - y2_output_loss: 2.4206 - y1_output_root_mean_squared_error: 0.8958 - y2_output_root_mean_squared_error: 1.5568 - val_loss: 3.9171 - val_y1_output_loss: 1.7121 - val_y2_output_loss: 2.1314 - val_y1_output_root_mean_squared_error: 1.3195 - val_y2_output_root_mean_squared_error: 1.4751
# Epoch 102/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.0320 - y1_output_loss: 0.9341 - y2_output_loss: 3.0665 - y1_output_root_mean_squared_error: 0.9693 - y2_output_root_mean_squared_error: 1.7586 - val_loss: 2.8828 - val_y1_output_loss: 0.5221 - val_y2_output_loss: 2.2715 - val_y1_output_root_mean_squared_error: 0.7344 - val_y2_output_root_mean_squared_error: 1.5308
# Epoch 103/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.9470 - y1_output_loss: 0.6497 - y2_output_loss: 2.3076 - y1_output_root_mean_squared_error: 0.8089 - y2_output_root_mean_squared_error: 1.5142 - val_loss: 6.9706 - val_y1_output_loss: 1.1175 - val_y2_output_loss: 5.7471 - val_y1_output_root_mean_squared_error: 1.0746 - val_y2_output_root_mean_squared_error: 2.4116
# Epoch 104/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.1948 - y1_output_loss: 0.7426 - y2_output_loss: 2.4404 - y1_output_root_mean_squared_error: 0.8586 - y2_output_root_mean_squared_error: 1.5677 - val_loss: 2.9009 - val_y1_output_loss: 0.9029 - val_y2_output_loss: 1.9441 - val_y1_output_root_mean_squared_error: 0.9557 - val_y2_output_root_mean_squared_error: 1.4098
# Epoch 105/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3998 - y1_output_loss: 0.7922 - y2_output_loss: 2.6693 - y1_output_root_mean_squared_error: 0.8882 - y2_output_root_mean_squared_error: 1.6158 - val_loss: 8.9192 - val_y1_output_loss: 3.6812 - val_y2_output_loss: 5.1995 - val_y1_output_root_mean_squared_error: 1.9338 - val_y2_output_root_mean_squared_error: 2.2759
# Epoch 106/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7318 - y1_output_loss: 0.7792 - y2_output_loss: 2.9388 - y1_output_root_mean_squared_error: 0.8862 - y2_output_root_mean_squared_error: 1.7166 - val_loss: 2.8392 - val_y1_output_loss: 0.6763 - val_y2_output_loss: 2.1020 - val_y1_output_root_mean_squared_error: 0.8337 - val_y2_output_root_mean_squared_error: 1.4643
# Epoch 107/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4135 - y1_output_loss: 0.8825 - y2_output_loss: 2.5200 - y1_output_root_mean_squared_error: 0.9335 - y2_output_root_mean_squared_error: 1.5944 - val_loss: 2.8539 - val_y1_output_loss: 0.6769 - val_y2_output_loss: 2.1098 - val_y1_output_root_mean_squared_error: 0.8251 - val_y2_output_root_mean_squared_error: 1.4741
# Epoch 108/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6534 - y1_output_loss: 0.5369 - y2_output_loss: 2.1034 - y1_output_root_mean_squared_error: 0.7337 - y2_output_root_mean_squared_error: 1.4543 - val_loss: 1.8115 - val_y1_output_loss: 0.4232 - val_y2_output_loss: 1.3361 - val_y1_output_root_mean_squared_error: 0.6595 - val_y2_output_root_mean_squared_error: 1.1732
# Epoch 109/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1493 - y1_output_loss: 0.6933 - y2_output_loss: 2.4340 - y1_output_root_mean_squared_error: 0.8339 - y2_output_root_mean_squared_error: 1.5665 - val_loss: 2.7626 - val_y1_output_loss: 0.5307 - val_y2_output_loss: 2.1575 - val_y1_output_root_mean_squared_error: 0.7334 - val_y2_output_root_mean_squared_error: 1.4915
# Epoch 110/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0679 - y1_output_loss: 0.8515 - y2_output_loss: 3.2060 - y1_output_root_mean_squared_error: 0.9211 - y2_output_root_mean_squared_error: 1.7943 - val_loss: 3.2055 - val_y1_output_loss: 1.3080 - val_y2_output_loss: 1.8115 - val_y1_output_root_mean_squared_error: 1.1579 - val_y2_output_root_mean_squared_error: 1.3656
# Epoch 111/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.1497 - y1_output_loss: 2.2971 - y2_output_loss: 4.8079 - y1_output_root_mean_squared_error: 1.5207 - y2_output_root_mean_squared_error: 2.1994 - val_loss: 2.4088 - val_y1_output_loss: 0.8881 - val_y2_output_loss: 1.4651 - val_y1_output_root_mean_squared_error: 0.9532 - val_y2_output_root_mean_squared_error: 1.2249
# Epoch 112/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6106 - y1_output_loss: 0.7260 - y2_output_loss: 1.8881 - y1_output_root_mean_squared_error: 0.8539 - y2_output_root_mean_squared_error: 1.3717 - val_loss: 4.5839 - val_y1_output_loss: 1.5484 - val_y2_output_loss: 2.9233 - val_y1_output_root_mean_squared_error: 1.2646 - val_y2_output_root_mean_squared_error: 1.7276
# Epoch 113/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4321 - y1_output_loss: 0.6285 - y2_output_loss: 1.8262 - y1_output_root_mean_squared_error: 0.7960 - y2_output_root_mean_squared_error: 1.3411 - val_loss: 10.2325 - val_y1_output_loss: 1.3454 - val_y2_output_loss: 8.7207 - val_y1_output_root_mean_squared_error: 1.1796 - val_y2_output_root_mean_squared_error: 2.9734
# Epoch 114/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.1801 - y1_output_loss: 0.6862 - y2_output_loss: 2.4767 - y1_output_root_mean_squared_error: 0.8301 - y2_output_root_mean_squared_error: 1.5783 - val_loss: 3.0686 - val_y1_output_loss: 0.8456 - val_y2_output_loss: 2.1473 - val_y1_output_root_mean_squared_error: 0.9285 - val_y2_output_root_mean_squared_error: 1.4854
# Epoch 115/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.3021 - y1_output_loss: 0.5034 - y2_output_loss: 1.7824 - y1_output_root_mean_squared_error: 0.7125 - y2_output_root_mean_squared_error: 1.3396 - val_loss: 1.8891 - val_y1_output_loss: 0.5845 - val_y2_output_loss: 1.2467 - val_y1_output_root_mean_squared_error: 0.7753 - val_y2_output_root_mean_squared_error: 1.1349
# Epoch 116/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.3068 - y1_output_loss: 1.8328 - y2_output_loss: 6.4070 - y1_output_root_mean_squared_error: 1.3592 - y2_output_root_mean_squared_error: 2.5415 - val_loss: 2.6201 - val_y1_output_loss: 0.7523 - val_y2_output_loss: 1.7969 - val_y1_output_root_mean_squared_error: 0.8811 - val_y2_output_root_mean_squared_error: 1.3579
# Epoch 117/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2525 - y1_output_loss: 0.7840 - y2_output_loss: 2.4991 - y1_output_root_mean_squared_error: 0.8854 - y2_output_root_mean_squared_error: 1.5712 - val_loss: 3.2372 - val_y1_output_loss: 1.5748 - val_y2_output_loss: 1.5688 - val_y1_output_root_mean_squared_error: 1.2763 - val_y2_output_root_mean_squared_error: 1.2681
# Epoch 118/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.6060 - y1_output_loss: 0.9470 - y2_output_loss: 2.6430 - y1_output_root_mean_squared_error: 0.9763 - y2_output_root_mean_squared_error: 1.6287 - val_loss: 3.7077 - val_y1_output_loss: 0.8788 - val_y2_output_loss: 2.6972 - val_y1_output_root_mean_squared_error: 0.9543 - val_y2_output_root_mean_squared_error: 1.6724
# Epoch 119/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.3372 - y1_output_loss: 0.9293 - y2_output_loss: 3.3831 - y1_output_root_mean_squared_error: 0.9677 - y2_output_root_mean_squared_error: 1.8441 - val_loss: 4.0627 - val_y1_output_loss: 0.7498 - val_y2_output_loss: 3.2075 - val_y1_output_root_mean_squared_error: 0.8710 - val_y2_output_root_mean_squared_error: 1.8177
# Epoch 120/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6947 - y1_output_loss: 0.6636 - y2_output_loss: 2.0254 - y1_output_root_mean_squared_error: 0.8144 - y2_output_root_mean_squared_error: 1.4253 - val_loss: 2.2138 - val_y1_output_loss: 0.6555 - val_y2_output_loss: 1.5109 - val_y1_output_root_mean_squared_error: 0.8088 - val_y2_output_root_mean_squared_error: 1.2489
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4117 - y1_output_loss: 0.1189 - y2_output_loss: 0.2901 - y1_output_root_mean_squared_error: 0.3449 - y2_output_root_mean_squared_error: 0.5410 - val_loss: 0.7722 - val_y1_output_loss: 0.1810 - val_y2_output_loss: 0.5666 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 0.7654
# Epoch 462/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2858 - y1_output_loss: 0.1105 - y2_output_loss: 0.1821 - y1_output_root_mean_squared_error: 0.3200 - y2_output_root_mean_squared_error: 0.4283 - val_loss: 0.7917 - val_y1_output_loss: 0.3200 - val_y2_output_loss: 0.4576 - val_y1_output_root_mean_squared_error: 0.5722 - val_y2_output_root_mean_squared_error: 0.6814
# Epoch 463/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3204 - y1_output_loss: 0.0988 - y2_output_loss: 0.2243 - y1_output_root_mean_squared_error: 0.3124 - y2_output_root_mean_squared_error: 0.4719 - val_loss: 0.9029 - val_y1_output_loss: 0.4169 - val_y2_output_loss: 0.4600 - val_y1_output_root_mean_squared_error: 0.6562 - val_y2_output_root_mean_squared_error: 0.6873
# Epoch 464/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3352 - y1_output_loss: 0.1108 - y2_output_loss: 0.2243 - y1_output_root_mean_squared_error: 0.3330 - y2_output_root_mean_squared_error: 0.4736 - val_loss: 0.7832 - val_y1_output_loss: 0.2577 - val_y2_output_loss: 0.5250 - val_y1_output_root_mean_squared_error: 0.5106 - val_y2_output_root_mean_squared_error: 0.7228
# Epoch 465/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3338 - y1_output_loss: 0.0985 - y2_output_loss: 0.2339 - y1_output_root_mean_squared_error: 0.3150 - y2_output_root_mean_squared_error: 0.4843 - val_loss: 0.9638 - val_y1_output_loss: 0.1959 - val_y2_output_loss: 0.7549 - val_y1_output_root_mean_squared_error: 0.4444 - val_y2_output_root_mean_squared_error: 0.8754
# Epoch 466/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3396 - y1_output_loss: 0.1077 - y2_output_loss: 0.2313 - y1_output_root_mean_squared_error: 0.3288 - y2_output_root_mean_squared_error: 0.4812 - val_loss: 1.1566 - val_y1_output_loss: 0.1988 - val_y2_output_loss: 0.9267 - val_y1_output_root_mean_squared_error: 0.4509 - val_y2_output_root_mean_squared_error: 0.9763
# Epoch 467/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4828 - y1_output_loss: 0.1244 - y2_output_loss: 0.3561 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.5979 - val_loss: 0.6587 - val_y1_output_loss: 0.1932 - val_y2_output_loss: 0.4493 - val_y1_output_root_mean_squared_error: 0.4447 - val_y2_output_root_mean_squared_error: 0.6789
# Epoch 468/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4038 - y1_output_loss: 0.1225 - y2_output_loss: 0.2785 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5295 - val_loss: 0.6422 - val_y1_output_loss: 0.1966 - val_y2_output_loss: 0.4356 - val_y1_output_root_mean_squared_error: 0.4447 - val_y2_output_root_mean_squared_error: 0.6667
# Epoch 469/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4139 - y1_output_loss: 0.1361 - y2_output_loss: 0.2743 - y1_output_root_mean_squared_error: 0.3706 - y2_output_root_mean_squared_error: 0.5259 - val_loss: 0.7770 - val_y1_output_loss: 0.2134 - val_y2_output_loss: 0.5534 - val_y1_output_root_mean_squared_error: 0.4626 - val_y2_output_root_mean_squared_error: 0.7503
# Epoch 470/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3664 - y1_output_loss: 0.1129 - y2_output_loss: 0.2525 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.5036 - val_loss: 0.9965 - val_y1_output_loss: 0.2473 - val_y2_output_loss: 0.7190 - val_y1_output_root_mean_squared_error: 0.5058 - val_y2_output_root_mean_squared_error: 0.8606
# Epoch 471/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3708 - y1_output_loss: 0.1182 - y2_output_loss: 0.2519 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.5023 - val_loss: 0.6655 - val_y1_output_loss: 0.2264 - val_y2_output_loss: 0.4206 - val_y1_output_root_mean_squared_error: 0.4842 - val_y2_output_root_mean_squared_error: 0.6566
# Epoch 472/500
# 614/614 [==============================] - 0s 131us/sample - loss: 1.2425 - y1_output_loss: 0.3133 - y2_output_loss: 0.9220 - y1_output_root_mean_squared_error: 0.5618 - y2_output_root_mean_squared_error: 0.9628 - val_loss: 1.6574 - val_y1_output_loss: 0.3149 - val_y2_output_loss: 1.2921 - val_y1_output_root_mean_squared_error: 0.5696 - val_y2_output_root_mean_squared_error: 1.1546
# Epoch 473/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4245 - y1_output_loss: 0.1228 - y2_output_loss: 0.3007 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5494 - val_loss: 1.0232 - val_y1_output_loss: 0.2641 - val_y2_output_loss: 0.7294 - val_y1_output_root_mean_squared_error: 0.5201 - val_y2_output_root_mean_squared_error: 0.8676
# Epoch 474/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3147 - y1_output_loss: 0.1123 - y2_output_loss: 0.2006 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.4490 - val_loss: 0.7300 - val_y1_output_loss: 0.1768 - val_y2_output_loss: 0.5311 - val_y1_output_root_mean_squared_error: 0.4263 - val_y2_output_root_mean_squared_error: 0.7404
# Epoch 475/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3316 - y1_output_loss: 0.1086 - y2_output_loss: 0.2232 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4718 - val_loss: 0.6695 - val_y1_output_loss: 0.2197 - val_y2_output_loss: 0.4450 - val_y1_output_root_mean_squared_error: 0.4721 - val_y2_output_root_mean_squared_error: 0.6683
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.2976 - y1_output_loss: 0.0992 - y2_output_loss: 0.1964 - y1_output_root_mean_squared_error: 0.3161 - y2_output_root_mean_squared_error: 0.4446 - val_loss: 0.6395 - val_y1_output_loss: 0.1947 - val_y2_output_loss: 0.4326 - val_y1_output_root_mean_squared_error: 0.4450 - val_y2_output_root_mean_squared_error: 0.6645
# Epoch 477/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3022 - y1_output_loss: 0.1059 - y2_output_loss: 0.1963 - y1_output_root_mean_squared_error: 0.3239 - y2_output_root_mean_squared_error: 0.4442 - val_loss: 0.7065 - val_y1_output_loss: 0.2357 - val_y2_output_loss: 0.4487 - val_y1_output_root_mean_squared_error: 0.4934 - val_y2_output_root_mean_squared_error: 0.6805
# Epoch 478/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4528 - y1_output_loss: 0.1186 - y2_output_loss: 0.3348 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.5775 - val_loss: 1.4588 - val_y1_output_loss: 0.1767 - val_y2_output_loss: 1.2450 - val_y1_output_root_mean_squared_error: 0.4252 - val_y2_output_root_mean_squared_error: 1.1305
# Epoch 479/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3772 - y1_output_loss: 0.1070 - y2_output_loss: 0.2710 - y1_output_root_mean_squared_error: 0.3272 - y2_output_root_mean_squared_error: 0.5198 - val_loss: 1.2096 - val_y1_output_loss: 0.2998 - val_y2_output_loss: 0.8819 - val_y1_output_root_mean_squared_error: 0.5544 - val_y2_output_root_mean_squared_error: 0.9498
# Epoch 480/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4850 - y1_output_loss: 0.1436 - y2_output_loss: 0.3392 - y1_output_root_mean_squared_error: 0.3802 - y2_output_root_mean_squared_error: 0.5835 - val_loss: 1.4030 - val_y1_output_loss: 0.2455 - val_y2_output_loss: 1.1313 - val_y1_output_root_mean_squared_error: 0.4998 - val_y2_output_root_mean_squared_error: 1.0739
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4380 - y1_output_loss: 0.1164 - y2_output_loss: 0.3189 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.5664 - val_loss: 0.6159 - val_y1_output_loss: 0.1671 - val_y2_output_loss: 0.4366 - val_y1_output_root_mean_squared_error: 0.4147 - val_y2_output_root_mean_squared_error: 0.6663
# Epoch 482/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.2916 - y1_output_loss: 0.0926 - y2_output_loss: 0.1985 - y1_output_root_mean_squared_error: 0.3045 - y2_output_root_mean_squared_error: 0.4459 - val_loss: 0.7391 - val_y1_output_loss: 0.1943 - val_y2_output_loss: 0.5235 - val_y1_output_root_mean_squared_error: 0.4484 - val_y2_output_root_mean_squared_error: 0.7335
# Epoch 483/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3211 - y1_output_loss: 0.1059 - y2_output_loss: 0.2136 - y1_output_root_mean_squared_error: 0.3252 - y2_output_root_mean_squared_error: 0.4640 - val_loss: 0.6613 - val_y1_output_loss: 0.1908 - val_y2_output_loss: 0.4640 - val_y1_output_root_mean_squared_error: 0.4377 - val_y2_output_root_mean_squared_error: 0.6854
# Epoch 484/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3266 - y1_output_loss: 0.1027 - y2_output_loss: 0.2242 - y1_output_root_mean_squared_error: 0.3216 - y2_output_root_mean_squared_error: 0.4724 - val_loss: 0.9299 - val_y1_output_loss: 0.2438 - val_y2_output_loss: 0.6872 - val_y1_output_root_mean_squared_error: 0.4980 - val_y2_output_root_mean_squared_error: 0.8258
# Epoch 485/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3330 - y1_output_loss: 0.1088 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4757 - val_loss: 1.0824 - val_y1_output_loss: 0.2619 - val_y2_output_loss: 0.8572 - val_y1_output_root_mean_squared_error: 0.5120 - val_y2_output_root_mean_squared_error: 0.9057
# Epoch 486/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4809 - y1_output_loss: 0.1265 - y2_output_loss: 0.3581 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5949 - val_loss: 1.5842 - val_y1_output_loss: 0.3095 - val_y2_output_loss: 1.2434 - val_y1_output_root_mean_squared_error: 0.5635 - val_y2_output_root_mean_squared_error: 1.1254
# Epoch 487/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4502 - y1_output_loss: 0.1256 - y2_output_loss: 0.3245 - y1_output_root_mean_squared_error: 0.3517 - y2_output_root_mean_squared_error: 0.5714 - val_loss: 1.2206 - val_y1_output_loss: 0.4516 - val_y2_output_loss: 0.7456 - val_y1_output_root_mean_squared_error: 0.6787 - val_y2_output_root_mean_squared_error: 0.8718
# Epoch 488/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4274 - y1_output_loss: 0.1235 - y2_output_loss: 0.3012 - y1_output_root_mean_squared_error: 0.3530 - y2_output_root_mean_squared_error: 0.5503 - val_loss: 0.6581 - val_y1_output_loss: 0.2201 - val_y2_output_loss: 0.4272 - val_y1_output_root_mean_squared_error: 0.4732 - val_y2_output_root_mean_squared_error: 0.6589
# Epoch 489/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3168 - y1_output_loss: 0.0997 - y2_output_loss: 0.2193 - y1_output_root_mean_squared_error: 0.3169 - y2_output_root_mean_squared_error: 0.4651 - val_loss: 1.3118 - val_y1_output_loss: 0.1659 - val_y2_output_loss: 1.1115 - val_y1_output_root_mean_squared_error: 0.4132 - val_y2_output_root_mean_squared_error: 1.0682
# Epoch 490/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5231 - y1_output_loss: 0.1357 - y2_output_loss: 0.3855 - y1_output_root_mean_squared_error: 0.3695 - y2_output_root_mean_squared_error: 0.6218 - val_loss: 1.0399 - val_y1_output_loss: 0.2245 - val_y2_output_loss: 0.7820 - val_y1_output_root_mean_squared_error: 0.4827 - val_y2_output_root_mean_squared_error: 0.8982
# Epoch 491/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3664 - y1_output_loss: 0.1108 - y2_output_loss: 0.2538 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.5053 - val_loss: 0.6932 - val_y1_output_loss: 0.2106 - val_y2_output_loss: 0.4696 - val_y1_output_root_mean_squared_error: 0.4630 - val_y2_output_root_mean_squared_error: 0.6920
# Epoch 492/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3179 - y1_output_loss: 0.0962 - y2_output_loss: 0.2235 - y1_output_root_mean_squared_error: 0.3095 - y2_output_root_mean_squared_error: 0.4713 - val_loss: 0.7698 - val_y1_output_loss: 0.2183 - val_y2_output_loss: 0.5391 - val_y1_output_root_mean_squared_error: 0.4713 - val_y2_output_root_mean_squared_error: 0.7401
# Epoch 493/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3391 - y1_output_loss: 0.1169 - y2_output_loss: 0.2200 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.4703 - val_loss: 0.6038 - val_y1_output_loss: 0.1728 - val_y2_output_loss: 0.4272 - val_y1_output_root_mean_squared_error: 0.4200 - val_y2_output_root_mean_squared_error: 0.6538
# Epoch 494/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3756 - y1_output_loss: 0.0993 - y2_output_loss: 0.2757 - y1_output_root_mean_squared_error: 0.3154 - y2_output_root_mean_squared_error: 0.5255 - val_loss: 0.9552 - val_y1_output_loss: 0.2525 - val_y2_output_loss: 0.6982 - val_y1_output_root_mean_squared_error: 0.5086 - val_y2_output_root_mean_squared_error: 0.8346
# Epoch 495/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3411 - y1_output_loss: 0.1103 - y2_output_loss: 0.2309 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.4806 - val_loss: 1.0378 - val_y1_output_loss: 0.1925 - val_y2_output_loss: 0.8231 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.9171
# Epoch 496/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3624 - y1_output_loss: 0.1299 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3557 - y2_output_root_mean_squared_error: 0.4856 - val_loss: 1.2561 - val_y1_output_loss: 0.4927 - val_y2_output_loss: 0.7230 - val_y1_output_root_mean_squared_error: 0.7136 - val_y2_output_root_mean_squared_error: 0.8642
# Epoch 497/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3255 - y1_output_loss: 0.1174 - y2_output_loss: 0.2062 - y1_output_root_mean_squared_error: 0.3435 - y2_output_root_mean_squared_error: 0.4556 - val_loss: 0.7276 - val_y1_output_loss: 0.1912 - val_y2_output_loss: 0.5170 - val_y1_output_root_mean_squared_error: 0.4434 - val_y2_output_root_mean_squared_error: 0.7287
# Epoch 498/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4114 - y1_output_loss: 0.1246 - y2_output_loss: 0.2848 - y1_output_root_mean_squared_error: 0.3531 - y2_output_root_mean_squared_error: 0.5354 - val_loss: 0.6508 - val_y1_output_loss: 0.1929 - val_y2_output_loss: 0.4494 - val_y1_output_root_mean_squared_error: 0.4444 - val_y2_output_root_mean_squared_error: 0.6733
# Epoch 499/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.2767 - y1_output_loss: 0.1101 - y2_output_loss: 0.1655 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.4079 - val_loss: 0.6311 - val_y1_output_loss: 0.2046 - val_y2_output_loss: 0.4149 - val_y1_output_root_mean_squared_error: 0.4590 - val_y2_output_root_mean_squared_error: 0.6485
# Epoch 500/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4436 - y1_output_loss: 0.1170 - y2_output_loss: 0.3261 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5715 - val_loss: 0.8614 - val_y1_output_loss: 0.1788 - val_y2_output_loss: 0.6704 - val_y1_output_root_mean_squared_error: 0.4278 - val_y2_output_root_mean_squared_error: 0.8237

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.8614 - y1_output_loss: 0.1833 - y2_output_loss: 0.6784 - y1_output_root_mean_squared_error: 0.4278 - y2_output_root_mean_squared_error: 0.8237
# Loss = 0.861446230442493, Y1_loss = 0.18333180248737335, Y1_mse = 0.42782166600227356, Y2_loss = 0.6784294247627258, Y2_mse = 0.8236594200134277

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
